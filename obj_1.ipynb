# %% [markdown]
# <a href="https://colab.research.google.com/github/zydanne-costa/Ondas_ADCP_SCO_Mar_Nov_2025/blob/main/obj_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Rotina para responder o objetivo 1
#
# Preciso extrair hs, tp e dp a cada burst. Plotar um gráfico com esses plots e com a variação de maré em cima alinhado com esses parâmetros.

# %% [markdown]
# Importando bibliotecas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# acesso ao drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# carregando dados de hs chuvoso
df_chu_hs = pd.read_csv('/content/drive/MyDrive/Ondas/Dados/Refinados/Hs_10min_CHU.csv')

# carregando dados de hs seco
df_sec_hs = pd.read_csv('/content/drive/MyDrive/Ondas/Dados/Refinados/Hs_10min_SEC.csv')

# %%
df_chu_hs
# Out:
#                 DataHora        Hs
# 0    2025-03-27 13:20:00       NaN
# 1    2025-03-27 13:40:00  0.498327
# 2    2025-03-27 14:00:00  0.546495
# 3    2025-03-27 14:20:00       NaN
# 4    2025-03-27 14:40:00  0.412204
# ..                   ...       ...
# 435  2025-04-02 14:20:00  0.592667
# 436  2025-04-02 14:40:00  0.645357
# 437  2025-04-02 15:00:00  0.878095
# 438  2025-04-02 15:20:00  0.651287
# 439  2025-04-02 15:40:00  0.610384
#
# [440 rows x 2 columns]
